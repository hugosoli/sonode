# %%
from gaia2 import *
import json

# %%
dsRaw = DataSet()
dsRaw.load("calindros-data-cruda.db")
dsClean = DataSet()
dsClean.load("calindros-data-clean.db")
dsClean.setReferenceDataSet(dsRaw)
euclideanMetric = DistanceFunctionFactory.create('euclidean', dsClean.layout())
euclideanView = View(dsClean)

# %%
similarSongs1 = euclideanView.nnSearch('NR__EL__PiezaCilindrero01_0030.720952.wav.sig', euclideanMetric).get(10)
print(similarSongs1)
# Out:
# (('NR__EL__PiezaCilindrero01_0030.720952.wav.sig', 0.0), ('NR__EL__PiezaCilindrero59_0043.999932.wav.sig', 1.0730857849121094), ('NR__EL__PiezaCilindrero06_0017.254512.wav.sig', 1.0951433181762695), ('NR__EL__PiezaCilindrero78_0048.664762.wav.sig', 1.1535507440567017), ('NR__EL__PiezaCilindrero07_0012.894830.wav.sig', 1.1821718215942383), ('NR__EL__PiezaCilindrero33_0016.940544.wav.sig', 1.2157554626464844), ('NR__EL__PiezaCilindrero39_0041.431315.wav.sig', 1.2319680452346802), ('NR__EL__PiezaCilindrero66_0045.531995.wav.sig', 1.2993186712265015), ('NR__EL__PiezaCilindrero35_0048.183152.wav.sig', 1.3252311944961548), ('NR__EL__PiezaCilindrero83_0003.104626.wav.sig', 1.36284339427948))

# %%
filter = 'WHERE value.average_loudness < 1 AND label.chords_key = "Eb"'
similarSongs2 = euclideanView.nnSearch('NR__EL__PiezaCilindrero01_0030.720952.wav.sig',euclideanMetric,filter).get(5)
print(similarSongs2)
file = open("filtro.txt","w")
for eachSnd in similarSongs2:
    file.write(eachSnd[0][:-4]+ "\n")
    print(eachSnd[0][:-4])
file.close()
# Out:
# (('NR__EL__PiezaCilindrero59_0012.269116.wav.sig', 1.4787979125976562), ('NR__EL__PiezaCilindrero05_0014.122268.wav.sig', 1.7605692148208618), ('NR__EL__PiezaCilindrero62_0005.836893.wav.sig', 1.8162094354629517), ('NR__EL__PiezaCilindrero47_0038.578776.wav.sig', 1.9193828105926514), ('NR__EL__PiezaCilindrero76_0028.398254.wav.sig', 1.945551872253418))
# NR__EL__PiezaCilindrero59_0012.269116.wav
# NR__EL__PiezaCilindrero05_0014.122268.wav
# NR__EL__PiezaCilindrero62_0005.836893.wav
# NR__EL__PiezaCilindrero47_0038.578776.wav
# NR__EL__PiezaCilindrero76_0028.398254.wav

# %%
p = dsRaw.point('NR__EL__PiezaCilindrero01_0030.720952.wav.sig')

# %%
dsClean.originalLayout().descriptorNames()
# Out:
# ('.lowlevel.average_loudness',
#  '.lowlevel.barkbands.dmean',
#  '.lowlevel.barkbands.dmean2',
#  '.lowlevel.barkbands.dvar',
#  '.lowlevel.barkbands.dvar2',
#  '.lowlevel.barkbands.max',
#  '.lowlevel.barkbands.mean',
#  '.lowlevel.barkbands.median',
#  '.lowlevel.barkbands.min',
#  '.lowlevel.barkbands.stdev',
#  '.lowlevel.barkbands.var',
#  '.lowlevel.barkbands_crest.dmean',
#  '.lowlevel.barkbands_crest.dmean2',
#  '.lowlevel.barkbands_crest.dvar',
#  '.lowlevel.barkbands_crest.dvar2',
#  '.lowlevel.barkbands_crest.max',
#  '.lowlevel.barkbands_crest.mean',
#  '.lowlevel.barkbands_crest.median',
#  '.lowlevel.barkbands_crest.min',
#  '.lowlevel.barkbands_crest.stdev',
#  '.lowlevel.barkbands_crest.var',
#  '.lowlevel.barkbands_flatness_db.dmean',
#  '.lowlevel.barkbands_flatness_db.dmean2',
#  '.lowlevel.barkbands_flatness_db.dvar',
#  '.lowlevel.barkbands_flatness_db.dvar2',
#  '.lowlevel.barkbands_flatness_db.max',
#  '.lowlevel.barkbands_flatness_db.mean',
# ...

# %%
dsRaw.layout().descriptorNames()
# Out:
# ('.lowLevel.average_loudness',
#  '.lowLevel.barkbands',
#  '.lowLevel.barkbands_kurtosis',
#  '.lowLevel.barkbands_skewness',
#  '.lowLevel.barkbands_spread',
#  '.lowLevel.dissonance',
#  '.lowLevel.hfc',
#  '.lowLevel.mfcc',
#  '.lowLevel.pitch',
#  '.lowLevel.pitch_instantaneous_confidence',
#  '.lowLevel.pitch_salience',
#  '.lowLevel.sccoeffs',
#  '.lowLevel.scvalleys',
#  '.lowLevel.silence_rate_20dB',
#  '.lowLevel.silence_rate_30dB',
#  '.lowLevel.silence_rate_60dB',
#  '.lowLevel.spectral_centroid',
#  '.lowLevel.spectral_complexity',
#  '.lowLevel.spectral_crest',
#  '.lowLevel.spectral_decrease',
#  '.lowLevel.spectral_energy',
#  '.lowLevel.spectral_energyband_high',
#  '.lowLevel.spectral_energyband_low',
#  '.lowLevel.spectral_energyband_middle_high',
#  '.lowLevel.spectral_energyband_middle_low',
#  '.lowLevel.spectral_flatness_db',
#  '.lowLevel.spectral_flux',
#  '.lowLevel.spectral_kurtosis',
#  '.lowLevel.spectral_rms',
#  '.lowLevel.spectral_rolloff',
# ...

# %%
valueNames = dsRaw.layout().descriptorNames(RealType)
labelNames = dsRaw.layout().descriptorNames(StringType)
todaLaData = {}
for pname in dsRaw.pointNames()[0:10]:
    p = dsRaw.point(pname)
    data = {}
    for name in labelNames:
        data[name] = p.label(name)
        print(name,p.label(name))
    print("******************")
    for name in valueNames:
        print(name,p.value(name))
        data[name] = p.value(name)
    todaLaData[pname] = data
json.dumps(todaLaData)
# Out:
# ('.metadata.audio_properties.analysis.downmix', 'mix')
# ('.metadata.audio_properties.codec', 'pcm_s16le')
# ('.metadata.audio_properties.md5_encoded', '5dfa2c7f560c24ccf20f238c2074be4e')
# ('.metadata.tags.file_name', 'NR__EL__PiezaCilindrero01_0000.000000.wav')
# ('.metadata.version.essentia', '2.1-beta6-dev')
# ('.metadata.version.essentia_git_sha', 'v2.1_beta5-313-g5395a707-dirty')
# ('.metadata.version.extractor', 'freesound 0.5')
# ('.tonal.chords_key', 'Ab')
# ('.tonal.chords_progression', ('Abm', 'Abm', 'Abm'))
# ('.tonal.chords_scale', 'minor')
# ('.tonal.key_edma.key', 'B')
# ('.tonal.key_edma.scale', 'major')
# ('.tonal.key_krumhansl.key', 'B')
# ('.tonal.key_krumhansl.scale', 'major')
# ('.tonal.key_temperley.key', 'B')
# ('.tonal.key_temperley.scale', 'major')
# ******************
# ('.lowlevel.average_loudness', 0.9478939175605774)
# ...
